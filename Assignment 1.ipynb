# %%
# Question 1 
a = 20 
b = 5 

divide = a//b
print(divide)
# Out:
# 4

# %%
# Question 2
name = 'Muhammad Saad Khan'
print(name)

wow = name.lower()
print(wow)
# Out:
# Muhammad Saad Khan
# muhammad saad khan

# %%
# Question 3 
var_1 = 'hello world from python'
print(var_1.title())
# Out:
# Hello World From Python

# %%
# Question 4 
x = 10 
y = 3 
xy = x%y
print(xy)
# Out:
# 1

# %%
# Question 5 
name = 'PYTHON'

lower_case = name.lower()
print(lower_case)
# Out:
# python

# %%
# Question 6
word = 'DataScience'
val_4 = len(word)
print(val_4)
# Out:
# 11

# %%
# Question 7
x = 7 
square = x*x
print(square)
# Out:
# 49

# %%
# Question 8
ok = 'hello'
val_2 = ok * 3
print(val_2)
# Out:
# hellohellohello

# %%
# Question 9
a = 15 
b = 10 
val_3 = bool(a>b)
print(val_3)
# Out:
# True

# %%
# Question 10
word = 'i love python programming'
print(word.capitalize())
# Out:
# I love python programming
